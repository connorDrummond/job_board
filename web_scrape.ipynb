# %%
from sqlalchemy import create_engine
from jobspy import scrape_jobs
import pandas as pd
  from sqlalchemy import create_engine
jobs_list = [
    "Software Engineer",
    "Data Engineer",
    "Data Scientist",
    "Data Analyst",
    "Analytics Engineer"
]

data = pd.DataFrame()

for job in jobs_list:
    jobs = scrape_jobs(
        site_name="indeed",
        search_term=job,
        google_search_term="Data engineer jobs near Kansas City, MO since yesterday",
        verbose=1,
        results_wanted=20000,
        is_remote=True,
        country_indeed='USA',
    )

    jobs_df = pd.DataFrame(jobs)
    data = pd.concat([data, jobs_df], axis=0, ignore_index=True)

conn_string = 'postgresql://postgres:14Cd1442$@database-1.cf28q0kociwu.us-east-2.rds.amazonaws.com:5432/postgres'
db = create_engine(conn_string)

data.to_sql('jobs', con=db, if_exists='append', index=False, schema = 'silver')

# %%
data
# Out:
#                        id    site  \
# 0     in-1c898ea3f45a64de  indeed
# 1     in-42f4fae480a2928e  indeed
# 2     in-558e59e1df353986  indeed
# 3     in-b43e8c2fc4731e33  indeed
# 4     in-95f11b9f4c44b432  indeed
# ...                   ...     ...
# 4984  in-e18150324879ec2d  indeed
# 4985  in-48ba928fbb616d8d  indeed
# 4986  in-d3ff4ec4cf878ce1  indeed
# 4987  in-ebe25b3fd6142a55  indeed
# 4988  in-d883151dbb458fe2  indeed
#
#                                                 job_url  \
# 0     https://www.indeed.com/viewjob?jk=1c898ea3f45a...
# 1     https://www.indeed.com/viewjob?jk=42f4fae480a2...
# 2     https://www.indeed.com/viewjob?jk=558e59e1df35...
# 3     https://www.indeed.com/viewjob?jk=b43e8c2fc473...
# 4     https://www.indeed.com/viewjob?jk=95f11b9f4c44...
# ...                                                 ...
# 4984  https://www.indeed.com/viewjob?jk=e18150324879...
# 4985  https://www.indeed.com/viewjob?jk=48ba928fbb61...
# 4986  https://www.indeed.com/viewjob?jk=d3ff4ec4cf87...
# 4987  https://www.indeed.com/viewjob?jk=ebe25b3fd614...
# 4988  https://www.indeed.com/viewjob?jk=d883151dbb45...
#
#                                          job_url_direct  \
# 0     https://tnl2.jometer.com/v2/job?jz=5wqzs1622bd...
# 1                           https://grnh.se/yz5t2hdn1us
# 2     https://strategictechpartners.hrmdirect.com/em...
# 3     https://careers.mantech.com/en_US/careers/JobD...
# 4     https://zillow.wd5.myworkdayjobs.com/en-US/Zil...
# ...                                                 ...
# 4984  https://searchcareers.caci.com/careers/job/144...
# 4985                        https://grnh.se/76u2yq4z9us
# 4986                        https://grnh.se/52ic9drr8us
# 4987  https://candidateportal.ceipal.com/job-details...
# 4988            https://apply.workable.com/j/69F88976DC
#
#                                                title  \
# 0                                Software Engineer I
# 1     Senior Software Engineer II - Android (Kotlin)
# 2                                 DevSecOps Engineer
# 3                            Java Software Developer
# 4                   Senior Machine Learning Engineer
# ...                                              ...
# 4984                           Senior GenAI Engineer
# 4985                           Senior Client Partner
# 4986  Solution Architect [U.S. Citizenship Required]
# 4987                     Senior Azure Data Architect
# 4988              Software Engineer - Web/ML Dev Ops
#
#                             company               location date_posted  \
# 0                              Uber      Sunnyvale, CA, US  2026-05-01
# 1                          Doximity  San Francisco, CA, US  2026-05-01
# 2     Strategic Technology Partners             Remote, US  2026-05-01
# 3                           MANTECH             Remote, US  2026-05-01
# 4                            Zillow             Remote, US  2026-05-01
# ...                             ...                    ...         ...
# 4984             CACI International             Remote, US  2026-01-21
# 4985                      KUNGFU.AI             Remote, US  2026-01-09
# 4986                  Via Logic LLC             Remote, US  2025-12-31
# 4987         CENTSTONE SERVICES LLC         Hazlet, NJ, US  2025-12-04
# 4988                         Chooch      San Mateo, CA, US  2025-06-09
#
#       job_type salary_source  ...  \
# 0     fulltime   direct_data  ...
# 1     fulltime   direct_data  ...
# 2          NaN           NaN  ...
# 3     fulltime           NaN  ...
# 4     fulltime   direct_data  ...
# ...        ...           ...  ...
# 4984  fulltime   direct_data  ...
# 4985       NaN           NaN  ...
# 4986  fulltime           NaN  ...
# 4987       NaN           NaN  ...
# 4988  fulltime           NaN  ...
#
#                                      company_addresses  company_num_employees  \
# 0                                    San Francisco, CA                10,000+
# 1                                    San Francisco, CA           501 to 1,000
# 2     3033 Wilson Blvd. Suite 700 Arlington, VA  22201               11 to 50
# 3                                          Herndon, VA        5,001 to 10,000
# 4                                          Seattle, WA        5,001 to 10,000
# ...                                                ...                    ...
# 4984                                        Reston, VA                10,000+
# 4985                                               NaN                    NaN
# 4986                                               NaN                    NaN
# 4987                                               NaN                    NaN
# 4988                                               NaN                    NaN
#
#            company_revenue                                company_description  \
# 0     more than $10B (USD)  We reimagine the way the world moves for the b...
# 1                      NaN  Doximity is the largest community of healthcar...
# 2                      NaN                        https://www.stpfederal.com/
# 3         $1B to $5B (USD)  MANTECH provides innovative technologies and s...
# 4     $100M to $500M (USD)             The work we do helps people get home.
# ...                    ...                                                ...
# 4984     $5B to $10B (USD)  CACI is ever vigilant in helping our customers...
# 4985                   NaN                                                NaN
# 4986                   NaN                                                NaN
# 4987                   NaN                                                NaN
# 4988                   NaN                                                NaN
#
#       skills experience_range company_rating company_reviews_count  \
# 0       None             None           None                  None
# 1       None             None           None                  None
# 2       None             None           None                  None
# 3       None             None           None                  None
# 4       None             None           None                  None
# ...      ...              ...            ...                   ...
# 4984    None             None           None                  None
# 4985    None             None           None                  None
# 4986    None             None           None                  None
# 4987    None             None           None                  None
# 4988    None             None           None                  None
#
#      vacancy_count work_from_home_type
# 0             None                None
# 1             None                None
# 2             None                None
# 3             None                None
# 4             None                None
# ...            ...                 ...
# 4984          None                None
# 4985          None                None
# 4986          None                None
# 4987          None                None
# 4988          None                None
#
# [4989 rows x 34 columns]

# %%
from sqlalchemy import create_engine
conn_string = 'postgresql://postgres:14Cd1442$@database-2.cf28q0kociwu.us-east-2.rds.amazonaws.com:5432/postgres'
db = create_engine(conn_string)

data.to_sql('jobs', con=db, if_exists='append', index=False, schema = 'silver')
# Out:
# 184
